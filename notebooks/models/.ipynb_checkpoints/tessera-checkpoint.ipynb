# %% [markdown]
# # TESSERA, frozen encoder (128-d embeddings)
#
# This notebook follows `src/models/tessera.py` and shows how the wrapper prepares Sentinel-2 and Sentinel-1 time series for the TESSERA encoder.
#
# Key properties:
# - Uses Sentinel-2 reflectance and Sentinel-1 VV/VH inputs.
# - Normalizes each modality with wrapper constants.
# - Appends day-of-year as an extra channel for each modality.
# - Pools the model output into one 128-dimensional embedding per parcel.

# %% [markdown]
# ## What TESSERA expects as input
#
# | Tensor | Shape | Meaning |
# | --- | --- | --- |
# | `s2_input` | `(N, T, 11)` | 10 S2 bands plus day-of-year |
# | `s1_input` | `(N, T, 3)` | VV, VH plus day-of-year |
# | output embedding | `(N, 128)` | pooled frozen representation |
#
# The wrapper keeps the public `encode()` API benchmark-shaped and hides the modality-specific normalization details.

# %%
import os
import sys
import importlib.util
from pathlib import Path
from types import SimpleNamespace

import numpy as np

REPO = Path.cwd()
while not (REPO / 'src').exists() and REPO.parent != REPO:
    REPO = REPO.parent
sys.path.insert(0, str(REPO))


def load(name, rel):
    spec = importlib.util.spec_from_file_location(name, REPO / rel)
    module = importlib.util.module_from_spec(spec)
    sys.modules[name] = module
    spec.loader.exec_module(module)
    return module

# %%
tessera = load('tessera_mod', 'src/models/tessera.py')

print('S2 bands:', tessera.TESSERA_S2_BANDS)
print('S1 bands:', tessera.TESSERA_S1_BANDS)
print('embedding dim:', tessera.TESSERA_EMBEDDING_DIM)
print('default weights:', tessera.DEFAULT_WEIGHTS)

# %%
rng = np.random.default_rng(7)
N, T = 4, 18

s2_bands = ['B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B11', 'B12', 'NDVI']
s1_bands = ['VV', 'VH']
climate_bands = ['temperature', 'precipitation', 'elevation', 'slope']

bench = SimpleNamespace(
    name='synthetic',
    s2=(rng.random((N, T, len(s2_bands))) * 5000).astype('float32'),
    s1=rng.normal(-12, 3, size=(N, T, len(s1_bands))).astype('float32'),
    climate=rng.normal(0, 1, size=(N, T, len(climate_bands))).astype('float32'),
    s2_mask=np.ones((N, T), dtype='float32'),
    s1_mask=np.ones((N, T), dtype='float32'),
    climate_mask=np.ones((N, T), dtype='float32'),
    doy=np.tile(np.linspace(15, 350, T), (N, 1)).astype('float32'),
    latlon=np.repeat(np.array([[11.0, 79.0]], dtype='float32'), N, axis=0),
    years=np.full(N, 2021, dtype='int64'),
    s2_bands=s2_bands,
    s1_bands=s1_bands,
    climate_bands=climate_bands,
)

print('s2', bench.s2.shape, bench.s2_bands)
print('s1', bench.s1.shape, bench.s1_bands)
print('climate', bench.climate.shape, bench.climate_bands)
print('doy', bench.doy.shape, 'latlon', bench.latlon.shape)

# %% [markdown]
# ## Wrapper mapping
#
# `_modality_input` is the model-specific conversion used internally by `encode`. It selects bands by name, applies benchmark masks, normalizes values, and appends DOY.

# %%
enc = tessera.TesseraEncoder(device='cpu')
s2_input = enc._modality_input(bench.s2, tessera.TESSERA_S2_BANDS, bench.s2_bands, tessera.S2_BAND_MEAN, tessera.S2_BAND_STD, bench.doy)
s1_input = enc._modality_input(bench.s1, tessera.TESSERA_S1_BANDS, bench.s1_bands, tessera.S1_BAND_MEAN, tessera.S1_BAND_STD, bench.doy)

print('s2_input', s2_input.shape)
print('s1_input', s1_input.shape)
print('s2 first sample, first timestep', np.round(s2_input[0, 0], 3))
print('s1 first sample, first timestep', np.round(s1_input[0, 0], 3))

# %% [markdown]
# ## Forward pass -> embedding
#
# The real forward pass requires the TESSERA checkpoint. Leave it disabled when all you need is to inspect input preparation.

# %%
RUN_REAL_FORWARD = False

enc = tessera.TesseraEncoder(device='cpu')
weights_path = Path(enc.weights_path or os.environ.get('TESSERA_WEIGHTS') or tessera.DEFAULT_WEIGHTS)

if not RUN_REAL_FORWARD:
    print('Set RUN_REAL_FORWARD = True to run the frozen encoder.')
elif not weights_path.exists():
    print('Skipping encode: weights not found at', weights_path)
else:
    emb = enc.encode(bench)
    print('embedding', emb.shape)
    print('first row, first 8 dims', np.round(emb[0, :8], 4))
